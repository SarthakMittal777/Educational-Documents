# %%
from matplotlib import pyplot as plt
# Out:
# Running cells with 'c:\msys64\mingw64\bin\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/msys64/mingw64/bin/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
# %matplotlib inline

# %%
plt.plot([1,2,3],[2,5,7],[1,2,3])

# %%
plt.show()

# %%
plt.title("SARTHAK DATA")
plt.xlabel("this is x label")
plt.ylabel("this is y label")
plt.plot([1,2,3,4,5,6,6,7],[1,12,33,222,11,11,2,4])

# %%
#printing 2 lines in single graph

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
x=[1,2,3,4,5]
y=[6,7,8,9,0]
x1=[0,9,8,7,6]
x2=[5,4,3,2,1]
plt.xlabel("SARTHAK")
plt.ylabel("SAM")
plt.title("MY FIRST GRAPH")
plt.plot(x,y, label="CLASS I",linewidth=3)
plt.plot(x1,x2, label="CLASS II")
plt.legend()
